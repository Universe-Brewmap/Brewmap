# %%
import os
import re
import requests
import pandas as pd

try:
    from config import API_KEYS
except ModuleNotFoundError:
    API_KEYS = {}

# %% [markdown]
# # 서울시 도로노선
# ## 1. 데이터 불러오기 및 데이터 확인

# %%
df_raw = pd.read_csv(
    "/Users/danha/Desktop/IT/project/team_project_brew_map/data/road.csv",
    encoding="cp949"
)

print("Shape:", df_raw.shape)
print("Columns:", df_raw.columns.tolist())
df_raw.head()
# Out:
# Shape: (14073, 4)
# Columns: ['idx', 'address', 'road_type', 'road_function']
#    idx   address road_type road_function
# 0    1     4.19로      일반도로          국지도로
# 1    2  4.19로11길      일반도로          국지도로
# 2    3  4.19로12길      일반도로          국지도로
# 3    4  4.19로13길      일반도로          국지도로
# 4    5  4.19로17길      일반도로          국지도로

# %%
print('=== 데이터 타입 ===')
print(df_raw.dtypes)
print()
print('=== 결측값 현황 ===')
print(df_raw.isnull().sum())
print()
print('=== 중복값 현황 ===')
print("전체 행 수:", len(df_raw))
print("완전 중복 행 수:", df_raw.duplicated().sum())
# Out:
# === 데이터 타입 ===
# idx               int64
# address          object
# road_type        object
# road_function    object
# dtype: object
#
# === 결측값 현황 ===
# idx              0
# address          0
# road_type        0
# road_function    0
# dtype: int64
#
# === 중복값 현황 ===
# 전체 행 수: 14073
# 완전 중복 행 수: 0

# %% [markdown]
# ## 2. 카카오맵 API를 이용하여 주소 정제 및 위경도 좌표 찾기

# %% [markdown]
# 카카오지도 REST API 키 발급 후 카카오맵 사용설정 상태 ON

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kakao_key  = os.getenv("KAKAO_REST_KEY")

# %% [markdown]
# ## 2.1 API 테스트

# %%
url = "	https://dapi.kakao.com/v2/local/search/address.json" #요청할 url 주소
headers = {"Authorization": f"KakaoAK REST API 키"} #REST API 키
params = {"query": "성수동2가 269-25"}  # 입력할 주소
resp = requests.get(url,headers=headers, params=params).json() #카카오 API 요청
                      
print(resp) #API 결과 출력
resp['documents'][0]['road_address']
# Out:
# {'documents': [{'address': {'address_name': '서울 성동구 성수동2가 269-25', 'b_code': '1120011500', 'h_code': '1120067000', 'main_address_no': '269', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '성동구', 'region_3depth_h_name': '성수2가1동', 'region_3depth_name': '성수동2가', 'sub_address_no': '25', 'x': '127.056741837461', 'y': '37.5402196364231'}, 'address_name': '서울 성동구 성수동2가 269-25', 'address_type': 'REGION_ADDR', 'road_address': {'address_name': '서울 성동구 성수이로10길 14', 'building_name': '에이스 하이엔드 성수타워', 'main_building_no': '14', 'region_1depth_name': '서울', 'region_2depth_name': '성동구', 'region_3depth_name': '성수동2가', 'road_name': '성수이로10길', 'sub_building_no': '', 'underground_yn': 'N', 'x': '127.056789858953', 'y': '37.5401307747523', 'zone_no': '04784'}, 'x': '127.056741837461', 'y': '37.5402196364231'}], 'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}
# {'address_name': '서울 성동구 성수이로10길 14',
#  'building_name': '에이스 하이엔드 성수타워',
#  'main_building_no': '14',
#  'region_1depth_name': '서울',
#  'region_2depth_name': '성동구',
#  'region_3depth_name': '성수동2가',
#  'road_name': '성수이로10길',
#  'sub_building_no': '',
#  'underground_yn': 'N',
#  'x': '127.056789858953',
#  'y': '37.5401307747523',
#  'zone_no': '04784'}

# %% [markdown]
# ### 2.2 전체 주소 카카오 API 호출

# %%
url = "	https://dapi.kakao.com/v2/local/search/address.json" #요청할 url 주소
headers = {"Authorization": f"KakaoAK REST API 키"} #REST API 키

for idx, add in df_raw['address'].items():
    params = {"query": add}
    resp = requests.get(url, headers=headers, params=params).json()

    docs = resp.get('documents', [])
    if not docs:
        continue

    road = docs[0].get('road_address')  # 없을 수도 있음

    if road:
        df_raw.loc[idx, 'road_address'] = road.get('address_name')
        df_raw.loc[idx, 'lat'] = road.get('y') # Y 좌표값, 경위도인 경우 위도(latitude)
        df_raw.loc[idx, 'lng'] = road.get('x') # X 좌표값, 경위도인 경우 경도(longitude)
    else:
        # road_address가 없으면 지번주소(address) 기준으로라도 좌표 저장
        addr = docs[0].get('address')
        if addr:
            df_raw.loc[idx, 'road_address'] = addr.get('address_name')
            df_raw.loc[idx, 'lat'] = addr.get('y')
            df_raw.loc[idx, 'lng'] = addr.get('x')

df_raw
# Out:
#          idx   address road_type road_function     road_address  \
# 0          1     4.19로      일반도로          국지도로     서울 강북구 4.19로
# 1          2  4.19로11길      일반도로          국지도로  서울 강북구 4.19로11길
# 2          3  4.19로12길      일반도로          국지도로  서울 강북구 4.19로12길
# 3          4  4.19로13길      일반도로          국지도로  서울 강북구 4.19로13길
# 4          5  4.19로17길      일반도로          국지도로  서울 강북구 4.19로17길
# ...      ...       ...       ...           ...              ...
# 14068  14069   희우정로20길      일반도로          국지도로   서울 마포구 희우정로20길
# 14069  14070   희우정로21길      일반도로          국지도로   서울 마포구 희우정로21길
# 14070  14071    희우정로3길      일반도로          국지도로    서울 마포구 희우정로3길
# 14071  14072    희우정로5길      일반도로          국지도로    서울 마포구 희우정로5길
# 14072  14073    희우정로7길      일반도로          국지도로    서울 마포구 희우정로7길
#
#                     lat               lng
# 0      37.6458517415689  127.007065129059
# 1      37.6455419841479  127.008425045298
# 2        37.64668385944   127.00599203326
# 3       37.644909106647  127.007480203776
# 4      37.6438457370333  127.006431324437
# ...                 ...               ...
# 14068  37.5558176914289  126.902510413936
# 14069  37.5549769264916  126.899343581688
# 14070  37.5494720272853  126.906943402838
# 14071  37.5503028091932  126.905771332963
# 14072  37.5509275551357  126.905088718384
#
# [14073 rows x 7 columns]

# %% [markdown]
# ## 3. 결측치
#
# ### 3.1 서울 여부 체크

# %%
total = len(df_raw)

seoul_cnt = df_raw['road_address'].str.contains('서울', na=False).sum()
na_cnt = df_raw['road_address'].isna().sum() #결측개수
not_seoul_only = total - seoul_cnt - na_cnt

print("전체:", total)
print("서울:", seoul_cnt)
print("서울 외:", not_seoul_only)
print("결측:", na_cnt)
# Out:
# 전체: 14073
# 서울: 13869
# 서울 외: 10
# 결측: 194

# %% [markdown]
# ### 3.2 결측 제거

# %%
# 제거 전 행 수 저장
before = len(df_raw)

# 서울 주소만 남기기 (서울 외 + 결측 자동 제거)
df_raw = df_raw[
    df_raw['road_address'].str.contains('서울', na=False)
]

after = len(df_raw)

print("=== 필터링 결과 ===")
print("제거된 행 수:", before - after)
print("최종 행 수:", after)
# Out:
# === 필터링 결과 ===
# 제거된 행 수: 204
# 최종 행 수: 13869

# %% [markdown]
# ## 4. idx 재설정 및 정렬

# %%
df_raw.sort_values(by = 'idx', inplace=True)
df_raw['idx'] = range(1, len(df_raw) + 1) # idx 번호 재부여
df_raw.reset_index(drop=True, inplace=True) # index 재설정
df_raw
# Out:
# /var/folders/hr/fhwqrjln55v6pjpz2zxrtw840000gn/T/ipykernel_43266/1719597356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw.sort_values(by = 'idx', inplace=True)
# /var/folders/hr/fhwqrjln55v6pjpz2zxrtw840000gn/T/ipykernel_43266/1719597356.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['idx'] = range(1, len(df_raw) + 1) # idx 번호 재부여
#          idx   address road_type road_function     road_address  \
# 0          1     4.19로      일반도로          국지도로     서울 강북구 4.19로
# 1          2  4.19로11길      일반도로          국지도로  서울 강북구 4.19로11길
# 2          3  4.19로12길      일반도로          국지도로  서울 강북구 4.19로12길
# 3          4  4.19로13길      일반도로          국지도로  서울 강북구 4.19로13길
# 4          5  4.19로17길      일반도로          국지도로  서울 강북구 4.19로17길
# ...      ...       ...       ...           ...              ...
# 13864  13865   희우정로20길      일반도로          국지도로   서울 마포구 희우정로20길
# 13865  13866   희우정로21길      일반도로          국지도로   서울 마포구 희우정로21길
# 13866  13867    희우정로3길      일반도로          국지도로    서울 마포구 희우정로3길
# 13867  13868    희우정로5길      일반도로          국지도로    서울 마포구 희우정로5길
# 13868  13869    희우정로7길      일반도로          국지도로    서울 마포구 희우정로7길
#
#                     lat               lng
# 0      37.6458517415689  127.007065129059
# 1      37.6455419841479  127.008425045298
# 2        37.64668385944   127.00599203326
# 3       37.644909106647  127.007480203776
# 4      37.6438457370333  127.006431324437
# ...                 ...               ...
# 13864  37.5558176914289  126.902510413936
# 13865  37.5549769264916  126.899343581688
# 13866  37.5494720272853  126.906943402838
# 13867  37.5503028091932  126.905771332963
# 13868  37.5509275551357  126.905088718384
#
# [13869 rows x 7 columns]

# %%
# 전처리 완료 데이터 저장

save_path = "/Users/danha/Desktop/IT/project/team_project_brew_map/data/dh/road.csv"

df_raw.to_csv(save_path, index=False, encoding="utf-8-sig")

print("저장 완료:", save_path)
# Out:
# 저장 완료: /Users/danha/Desktop/IT/project/team_project_brew_map/data/dh/road.csv
