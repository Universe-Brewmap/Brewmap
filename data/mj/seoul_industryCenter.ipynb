# %%
import requests 
import os
from dotenv import load_dotenv

# %%
# env 파일 로드
load_dotenv()

# %%
apikey  = os.getenv("MJ_APIKEY")     # 인증키
start_index = "1"    # 요청시작위치
end_index   = "100"  # 요청종료위치

url= f"http://openapi.seoul.go.kr:8088/{apikey}/json/InfoBizcenterApply/1/5/"

params ={'serviceKey' : apikey, 'LAWD_CD' : '11110', 'DEAL_YMD' : '201512' }

response = requests.get(url, params=params)
print(response.content.decode('utf-8'))
# Out:
# <RESULT><CODE>INFO-100</CODE><MESSAGE><![CDATA[인증키가 유효하지 않습니다.
# 인증키가 없는 경우, 열린 데이터 광장 홈페이지에서 인증키를 신청하십시오.]]></MESSAGE></RESULT>
